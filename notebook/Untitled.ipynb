# %%
import pandas as pd
df= pd.read_csv("../dataset_csv/cupid_algorithm_dataset.csv")
df.shape
# Out:
# (100000, 30)

# %%
df.columns
# Out:
# Index(['pair_id', 'a_age', 'a_education', 'a_location', 'a_career_field',
#        'a_career_ambition', 'a_openness', 'a_extraversion', 'a_agreeableness',
#        'a_conscientiousness', 'a_chronotype', 'a_spontaneity',
#        'a_love_language', 'a_emotional_expressiveness', 'b_age', 'b_education',
#        'b_location', 'b_career_field', 'b_career_ambition', 'b_openness',
#        'b_extraversion', 'b_agreeableness', 'b_conscientiousness',
#        'b_chronotype', 'b_spontaneity', 'b_love_language',
#        'b_emotional_expressiveness', 'compatibility_score', 'compatible',
#        'relationship_longevity_months'],
#       dtype='str')

# %%
df["relationship_longevity_months"].describe()
# Out:
# count    100000.000000
# mean         68.906250
# std          21.334574
# min           0.000000
# 25%          54.000000
# 50%          69.000000
# 75%          83.000000
# max         120.000000
# Name: relationship_longevity_months, dtype: float64

# %%
df
# Out:
#        pair_id  a_age  a_education a_location    a_career_field  \
# 0            1     46            3   Suburban        Healthcare
# 1            2     32            2   Suburban              Tech
# 2            3     25            4      Rural         Marketing
# 3            4     38            4   Suburban           Finance
# 4            5     36            2      Rural  Entrepreneurship
# ...        ...    ...          ...        ...               ...
# 99995    99996     54            2      Urban        Healthcare
# 99996    99997     44            4   Suburban           Finance
# 99997    99998     40            3      Urban         Marketing
# 99998    99999     43            2      Urban       Engineering
# 99999   100000     22            4   Suburban         Education
#
#        a_career_ambition  a_openness  a_extraversion  a_agreeableness  \
# 0                   0.23        0.67            0.78             0.32
# ...
